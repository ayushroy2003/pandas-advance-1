# %%
import pandas as pd

# %% [markdown]
# Q1. List any five functions of the pandas library with execution.
#
# Ans -

# %% [markdown]
# The five function of the pandas library are
#
# 1 - pd.Dataframe(): it is used to create a two-dimensional heterogenous object which manuplate its data

# %%
#execution  example pd.Dataframe()
df = pd.DataFrame({"NAME" : ["AYUSH" , "NIRITA" ,"RAJESH"],
                   "AGE" : [20,40,45],
                   "COUNTRY" : ["US" ,"INDIA" , "INDIA"],
                  })
                  
df
# Out:
#      NAME  AGE COUNTRY
# 0   AYUSH   20      US
# 1  NIRITA   40   INDIA
# 2  RAJESH   45   INDIA

# %% [markdown]
# 2 - pd.Series(): it is used to create a one dimensional homogeneous object

# %%
# execution example pd.Series
df1 = pd.Series([22,33,4,44,44,5,5])
df1
# Out:
# 0    22
# 1    33
# 2     4
# 3    44
# 4    44
# 5     5
# 6     5
# dtype: int64

# %% [markdown]
# 3 - pd.merge() - it is used to merge to Dataframe on specified column

# %%
#execution example pd.merge()
df3 = pd.DataFrame({'NAME' : ['AYUSH' , 'NIRITA' , 'RAJESH'] ,'SALARY' : [500000000,1000000,20000000]})
df4 = pd.DataFrame({'NAME' : ['SWETA' , 'SIMRAN'] , 'SALARY' : [4000000,600000]})

merge_df = pd.merge(df3,df4 ,on='NAME' ,how='outer')

# %%
merge_df
# Out:
#      NAME     SALARY_x   SALARY_y
# 0   AYUSH  500000000.0        NaN
# 1  NIRITA    1000000.0        NaN
# 2  RAJESH   20000000.0        NaN
# 3   SWETA          NaN  4000000.0
# 4  SIMRAN          NaN   600000.0

# %% [markdown]
# 4 - pd.Timestamp() : it is used to convert the data types of the specified column to datatime

# %%
# execution of pd.Timestamp

date = pd.Timestamp(2023 , 11,23 , 2,56,34)

print(date)
# Out:
# 2023-11-23 02:56:34

# %% [markdown]
# 5 - pd.read_csv() : it is used to read csv  files and return the dataframe object

# %%
#execution example pd.read_csv
csv_df = pd.read_csv("services.csv")
csv_df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
import pandas as pd

def reindex_dataframe(df):
    new_index = pd.Series(range(1, len(df) * 2, 2), name='new_index')
    df_reindexed = df.set_index(new_index)
    return df_reindexed

# Example usage:
# Assuming df is your original DataFrame with columns 'A', 'B', and 'C'
df = pd.DataFrame({'A': [10, 20, 30], 'B': [40, 50, 60], 'C': [70, 80, 90]})

# Call the function to re-index the DataFrame
df_reindexed = reindex_dataframe(df)

# Display the original and re-indexed DataFrames
print("Original DataFrame:")
print(df)
print("\nRe-indexed DataFrame:")
print(df_reindexed)
# Out:
# Original DataFrame:
#     A   B   C
# 0  10  40  70
# 1  20  50  80
# 2  30  60  90
#
# Re-indexed DataFrame:
#             A   B   C
# new_index
# 1          10  40  70
# 3          20  50  80
# 5          30  60  90

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.

# %%
df = pd.DataFrame({ "Values" : [100,200,300,400,500]})

def sum_of_first_3_numbers(df):
    sum_of_three = df["Values"].head(3).sum()
    print("the sum of first three values is :", sum_of_three)

# %%
sum_of_first_3_numbers(df)
# Out:
# the sum of first three values is : 600

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df = pd.DataFrame({"Text" : ["python", "pandas" , "data science" , "pwskills","machine learning" ]})

df["word_count"] = df["Text"].apply(len)

df
# Out:
#                Text  word_count
# 0            python           6
# 1            pandas           6
# 2      data science          12
# 3          pwskills           8
# 4  machine learning          16

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different
#
# Ans
#
# DataFrame.size() - this method returns the total number of element in the dataframe . it calculate the size by multipying the numbers of row by the column in dataframe the result is the total count of cells including NaN or missing values
#
# DataFrame.shape() - it returns a tuple representing the dimensions (number of rows and column) of the DataFrame

# %% [markdown]
# Q6. Which function of pandas do we use to read an excel file?
#
# Ans - "pd.read_excel()" function is used to read excel file

# %% [markdown]
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address
#
#
# The username is the part of the email address that appears before the '@' symbol. For example, if the
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
# function should extract the username from each email address and store it in the new 'Username'
# column.

# %%
df = pd.DataFrame({"Email":["royayush@gmai.com" , "sweta@gmai.com" , "simran@gmail.com"]})

df["Username"] = df["Email"].str.split('@').str[0]
df
# Out:
#                Email  Username
# 0  royayush@gmai.com  royayush
# 1     sweta@gmai.com     sweta
# 2   simran@gmail.com    simran

# %% [markdown]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.
#
# For example, if df contains the following values:
#
#  A B C
#
# 0 3 5 1
#
# 1 8 2 7
#
# 2 6 9 4
#
# 3 2 3 5
#
# 4 9 1 2
#
# Your function should select the following rows: A B C
#
# 1 8 2 7
#
# 4 9 1 2
#
# The function should return a new DataFrame that contains only the selected rows
#
# Ans -

# %%
def select_rows(df):
    mask = (df['A'] > 5) & (df['B'] < 10)
    selected_rows = df[mask]
    return selected_rows


df = pd.DataFrame({
    'A': [3, 8, 6, 2, 9],
    'B': [5, 2, 9, 3, 1],
    'C': [1, 7, 4, 5, 2]
})


selected_rows = select_rows(df)


print("Original DataFrame:")
print(df)
print("\nSelected Rows:")
print(selected_rows)
# Out:
# Original DataFrame:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2
#
# Selected Rows:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column

# %%
df = pd.DataFrame({"Value" : [100,200,300,400,1000,2000,3000,4000]})

def calculate_stat(df):
    mean = df["Value"].mean()
    median = df["Value"].median()
    standar_deviation = df["Value"].std()
    print("Mean:" ,mean,"Median:",median,"Standard Deviation:",standar_deviation)

calculate_stat(df)
# Out:
# Mean: 1375.0 Median: 700.0 Standard Deviation: 1472.3644735109383

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day

# %%
def add_moving_avg(df):
    df["Moving Average"] = df["sales"].rolling(window=7 , min_periods=1).mean()
    return df

df = pd.DataFrame({
    "date" : pd.date_range('2023-01-01', '2023-01-10'),
    "sales" : [100,200,250,300,400,450,500,550,600,650]
})

add_moving_avg(df)
# Out:
#         date  sales  Moving Average
# 0 2023-01-01    100      100.000000
# 1 2023-01-02    200      150.000000
# 2 2023-01-03    250      183.333333
# 3 2023-01-04    300      212.500000
# 4 2023-01-05    400      250.000000
# 5 2023-01-06    450      283.333333
# 6 2023-01-07    500      314.285714
# 7 2023-01-08    550      378.571429
# 8 2023-01-09    600      435.714286
# 9 2023-01-10    650      492.857143

# %% [markdown]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.
#
# For example, if df contains the following values:
#
#     Date
#
# 0 2023-01-01
#
# 1 2023-01-02
#
# 2 2023-01-03
#
# 3 2023-01-04
#
# 4 2023-01-05
#
# Your function should create the following DataFrame:
#
#
#       Date Weekday
#
# 0 2023-01-01 Sunday
#
# 1 2023-01-02 Monday
#
# 2 2023-01-03 Tuesday
#
# 3 2023-01-04 Wednesday
#
# 4 2023-01-05 Thursday
#
# The function should return the modified DataFrame.

# %%
def add_weekday_column(df):
    df["weekday"] = df["date"].dt.day_name()
    return df

df = pd.DataFrame({
    "date" : pd.date_range(start='2023-01-01' ,periods=5)
})

add_weekday_column(df)
# Out:
#         date    weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
def selecte_date(df):
    start_date = "2023-01-01"
    end_date ="2023-01-31"
    mask = (df["date"] >= start_date) & (df["date"] <= end_date)
    selected_rows = df[mask]
    return selected_rows

df = pd.DataFrame({'date': pd.date_range('2023-01-01', '2023-03-15')})

selecte_date(df)
# Out:
#          date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05
# 5  2023-01-06
# 6  2023-01-07
# 7  2023-01-08
# 8  2023-01-09
# 9  2023-01-10
# 10 2023-01-11
# 11 2023-01-12
# 12 2023-01-13
# 13 2023-01-14
# 14 2023-01-15
# 15 2023-01-16
# 16 2023-01-17
# 17 2023-01-18
# 18 2023-01-19
# 19 2023-01-20
# 20 2023-01-21
# 21 2023-01-22
# 22 2023-01-23
# 23 2023-01-24
# 24 2023-01-25
# 25 2023-01-26
# 26 2023-01-27
# 27 2023-01-28
# 28 2023-01-29
# 29 2023-01-30
# 30 2023-01-31

# %% [markdown]
# Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported?
#
# Ans -

# %% [markdown]
# To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported is "pandas library"
